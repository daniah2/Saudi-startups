# %%
import pandas as pd

# %% [markdown]
# # Load Dataset
#
# This code loads the dataset from `NewDatasetCollection.csv` and displays its shape before any cleaning, along with the first few rows.

# %%
df = pd.read_csv("NewDatasetCollection.csv")

# %%
print("Shape before cleaning:", df.shape)
df.head()
# Out:
# Shape before cleaning: (466, 17)
#       Name                   Website Featured           Stage  \
# 0     Lean   https://www.leantech.me      NaN        Series B
# 1  Foodics  https://www.foodics.com/      NaN        Series C
# 2    Salla        https://salla.com/     True  Private Equity
# 3     Nana        https://nana.co/en     True        Series C
# 4     Mozn       https://www.mozn.sa     True    Pre-Series B
#
#                         Industry                                       Tags  \
# 0             Financial Services                     Fintech Infrastructure
# 1  Technology ,Food & Beverages                     SaaS,Financial Solution
# 2                    Technology                                        SaaS
# 3              Food & Beverages   Last Mile Delivery,Marketplace,E-Commerce
# 4                    Technology                       AI & Machine Learning
#
#    Region    Startup HQ  NumOfTags Funding (USD)      CompanySize  \
# 0  Riyadh  Saudi Arabia          1     15M – 30M  Startup / Small
# 1  Riyadh  Saudi Arabia          2     25M – 50M  Startup / Small
# 2  Makkah  Saudi Arabia          1   50M – 500M+            Large
# 3  Riyadh  Saudi Arabia          3     25M – 50M  Startup / Small
# 4  Riyadh  Saudi Arabia          1     10M – 18M        Mid-level
#
#    Funding_min  rate_percent Allign with 2030 Funding_Avg Opportunity_Level  \
# 0   15000000.0         75.60              Yes      22.50M              High
# 1   25000000.0         75.60              Yes      37.50M              High
# 2   50000000.0         13.68              Yes     275.00M              High
# 3   25000000.0         75.60              Yes      37.50M              High
# 4   10000000.0         75.60              Yes      14.00M            Medium
#
#    Year of establishment
# 0                 2019.0
# 1                 2014.0
# 2                 2016.0
# 3                 2016.0
# 4                 2017.0

# %% [markdown]
# # Data Cleaning
# #### Our dataset contained some missing values, and outliers that could affect the accuracy of our analysis. Therefore, we performed several cleaning steps to ensure data quality:
# #### 1. Handled Missing Values: Filled columns with the correct text or number .
# #### 2. Treated Outliers: Used the Interquartile Range (IQR) method to detect and remove extreme values.
# #### 3. Standardized Data Types: Converted columns to appropriate formats (e.g., dates, categories).
# #### 4. Normalized Text Data: Removed extra spaces and converted all text to lowercase for consistency.
# #### 5. Saved Cleaned Data: Exported the cleaned dataset into a processed file for further analysis.

# %% [markdown]
# ### Dataset Information
#
# This command displays a concise summary of the dataset, including the number of non-null entries, column names, and data types.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466 entries, 0 to 465
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   466 non-null    object
#  1   Website                465 non-null    object
#  2   Featured               56 non-null     object
#  3   Stage                  466 non-null    object
#  4   Industry               466 non-null    object
#  5   Tags                   457 non-null    object
#  6   Region                 466 non-null    object
#  7   Startup HQ             466 non-null    object
#  8   NumOfTags              466 non-null    int64
#  9   Funding (USD)          466 non-null    object
#  10  CompanySize            466 non-null    object
#  11  Funding_min            466 non-null    float64
#  12  rate_percent           466 non-null    float64
#  13  Allign with 2030       466 non-null    object
#  14  Funding_Avg            466 non-null    object
#  15  Opportunity_Level      466 non-null    object
#  16  Year of establishment  279 non-null    float64
# dtypes: float64(3), int64(1), object(13)
# memory usage: 62.0+ KB

# %%
"""
We identified three columns with missing values: Featured, Tags, and Website.

"""
missing_value = df.isnull().sum()
missing_value
# Out:
# Name                       0
# Website                    1
# Featured                 410
# Stage                      0
# Industry                   0
# Tags                       9
# Region                     0
# Startup HQ                 0
# NumOfTags                  0
# Funding (USD)              0
# CompanySize                0
# Funding_min                0
# rate_percent               0
# Allign with 2030           0
# Funding_Avg                0
# Opportunity_Level          0
# Year of establishment    187
# dtype: int64

# %%
df["Year of establishment"] = df["Year of establishment"].fillna(0).astype(int)

# %%
df[df['Website'].isnull()]
# Out:
#               Name Website Featured     Stage     Industry Tags  Region  \
# 343  AI Atlas Inc.     NaN      NaN  Pre-Seed  Technology   NaN  Riyadh
#
#        Startup HQ  NumOfTags Funding (USD)      CompanySize  Funding_min  \
# 343  Saudi Arabia          0     500K – 2M  Startup / Small  500000000.0
#
#      rate_percent Allign with 2030 Funding_Avg Opportunity_Level  \
# 343          75.6               No       1.25M               Low
#
#      Year of establishment
# 343                      0

# %%
"""
For the Website column, only one value was missing. 
We addressed this by retrieving the company’s website URL and assigning it to the corresponding row.

"""
web = "https://www.aiatlasinc.ca"
df['Website'] = df['Website'].fillna(web)

# %%
"""
For the Tags column, we handled missing values by first checking each company’s website and LinkedIn profile to identify a tag related to its industry, 
which we then used to fill the missing entries. 
In cases where companies did not have sufficient data, 
we referred to similar companies with the same activity and assigned their tags accordingly. 
To maintain consistency, we kept the tags general rather than highly specific.

"""
df["Tags"].isna().sum()
# Out:
# np.int64(9)

# %%
filling_nan_tags = {
    "Financial Services" : "Fintech Infrastructure" , 
    "Travel & Tourism"   : "Marketplace" , 
    "Technology" : "SaaS" , 
    "Art & Design,Construction": "Design Services" ,
    "Technology ,Real Estate,Financial Services": "SaaS,RegTech,Financial Solution" , 
    "Technology ,Financial Services" : "Financial Solution" ,  
    "Financial Services,Retail" :  "Financial Solution" ,    
}

# %%
df["Industry"] = df["Industry"].str.strip()
df.loc[df["Tags"].isna(), "Tags"] = df.loc[df["Tags"].isna(), "Industry"].map(filling_nan_tags)

# %%
"""
The Featured column was not relevant to our analysis and contained around 90% missing values; therefore, we decided to drop it.

"""

df.drop(columns=['Featured'], inplace=True)
df.head(10)
# Out:
#        Name                   Website           Stage  \
# 0      Lean   https://www.leantech.me        Series B
# 1   Foodics  https://www.foodics.com/        Series C
# 2     Salla        https://salla.com/  Private Equity
# 3      Nana        https://nana.co/en        Series C
# 4      Mozn       https://www.mozn.sa    Pre-Series B
# 5     Rewaa     https://rewaatech.com        Series A
# 6       Zid           https://zid.sa/        Series B
# 7  Classera      https://classera.com        Series A
# 8   Gathern        https://gathern.co    Pre-Series A
# 9      Sary   https://www.sary.com/en        Series C
#
#                        Industry                                       Tags  \
# 0            Financial Services                     Fintech Infrastructure
# 1  Technology ,Food & Beverages                    SaaS,Financial Solution
# 2                    Technology                                       SaaS
# 3              Food & Beverages  Last Mile Delivery,Marketplace,E-Commerce
# 4                    Technology                      AI & Machine Learning
# 5                    Technology                                   SaaS,ERP
# 6            Technology ,Retail                            SaaS,E-Commerce
# 7                     Education                                       SaaS
# 8  Travel & Tourism,Real Estate                    Marketplace,Hospitality
# 9      Food & Beverages ,Retail                  B2B Financing,Marketplace
#
#    Region    Startup HQ  NumOfTags Funding (USD)      CompanySize  \
# 0  Riyadh  Saudi Arabia          1     15M – 30M  Startup / Small
# 1  Riyadh  Saudi Arabia          2     25M – 50M  Startup / Small
# 2  Makkah  Saudi Arabia          1   50M – 500M+            Large
# 3  Riyadh  Saudi Arabia          3     25M – 50M  Startup / Small
# 4  Riyadh  Saudi Arabia          1     10M – 18M        Mid-level
# 5  Riyadh  Saudi Arabia          2      6M – 15M  Startup / Small
# 6  Riyadh  Saudi Arabia          2     15M – 30M  Startup / Small
# 7  Makkah  Saudi Arabia          1      6M – 15M  Startup / Small
# 8  Riyadh  Saudi Arabia          2       2M – 6M  Startup / Small
# 9  Riyadh  Saudi Arabia          2     25M – 50M  Startup / Small
#
#    Funding_min  rate_percent Allign with 2030 Funding_Avg Opportunity_Level  \
# 0   15000000.0         75.60              Yes      22.50M              High
# 1   25000000.0         75.60              Yes      37.50M              High
# 2   50000000.0         13.68              Yes     275.00M              High
# 3   25000000.0         75.60              Yes      37.50M              High
# 4   10000000.0         75.60              Yes      14.00M            Medium
# 5    6000000.0         75.60              Yes      10.50M            Medium
# 6   15000000.0         75.60              Yes      22.50M              High
# 7    6000000.0         13.68              Yes      10.50M            Medium
# 8    2000000.0         75.60              Yes       4.00M            Medium
# 9   25000000.0         75.60              Yes      37.50M              High
#
#    Year of establishment
# 0                   2019
# 1                   2014
# 2                   2016
# 3                   2016
# 4                   2017
# 5                   2018
# 6                   2017
# 7                   2012
# 8                   2016
# 9                   2018

# %%
"""
Status of missing values after applying the handling process.
"""
missing_value = df.isnull().sum()
missing_value
# Out:
# Name                     0
# Website                  0
# Stage                    0
# Industry                 0
# Tags                     0
# Region                   0
# Startup HQ               0
# NumOfTags                0
# Funding (USD)            0
# CompanySize              0
# Funding_min              0
# rate_percent             0
# Allign with 2030         0
# Funding_Avg              0
# Opportunity_Level        0
# Year of establishment    0
# dtype: int64

# %%
"""
No duplicate values were found in the dataset.
"""
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Removing Duplicate Companies
#
# This code identifies specific companies listed in `companies_to_dedup` that have duplicate entries in the dataset.
# For each company with multiple rows, it removes the first occurrence and resets the DataFrame index.
# Finally, it displays the remaining rows for these companies to verify de-duplication.

# %%
companies_to_dedup = ["Truc-King","Resal", "Rintel", "Maghsala", "COGNNA", "Dunes Aero"]

for company in companies_to_dedup:
    company_rows = df[df["Name"] == company]
    
    if len(company_rows) > 1:
        index_to_drop = company_rows.index[0]
        df = df.drop(index_to_drop)
df = df.reset_index(drop=True)

df[df["Name"].isin(companies_to_dedup)]
# Out:
#            Name                   Website         Stage  \
# 222       Resal              Www.resal.me  Pre-Series B
# 308   Truc-King         www.truc-king.com          Seed
# 336  Dunes Aero             Dunesaero.com          Seed
# 352      COGNNA   https://www.cognna.com/          Seed
# 380    Maghsala  https://www.maghsala.co/      Pre-Seed
# 405      Rintel    https://www.rintel.co/      Pre-Seed
#
#                                               Industry  \
# 222                     Technology ,Financial Services
# 308  Transportation & Automotive,Technology ,Logistics
# 336                                         Technology
# 352                                Technology ,Defence
# 380                                   Consumer Service
# 405                                   Food & Beverages
#
#                                                   Tags  Region    Startup HQ  \
# 222                                 Financial Solution  Makkah  Saudi Arabia
# 308  Aggregator,AI & Machine Learning,Autonomous Dr...  Riyadh  Saudi Arabia
# 336  Hardware & loT & Drones,AgriTech,AI & Machine ...  Makkah  Saudi Arabia
# 352                                    Cyber Security   Riyadh  Saudi Arabia
# 380                                        Marketplace  Riyadh  Saudi Arabia
# 405                                  Consumer Services  Riyadh  Saudi Arabia
#
#      NumOfTags Funding (USD)      CompanySize  Funding_min  rate_percent  \
# 222          0     10M – 18M        Mid-level   10000000.0         13.68
# 308         10       1M – 3M  Startup / Small    1000000.0         75.60
# 336          7       1M – 3M  Startup / Small    1000000.0         13.68
# 352          1       1M – 3M  Startup / Small    1000000.0         75.60
# 380          1     500K – 2M  Startup / Small  500000000.0         75.60
# 405          1     500K – 2M  Startup / Small  500000000.0         75.60
#
#     Allign with 2030 Funding_Avg Opportunity_Level  Year of establishment
# 222               No      14.00M            Medium                   2018
# 308              Yes       2.00M            Medium                   2024
# 336              Yes       2.00M            Medium                   2022
# 352              Yes       2.00M            Medium                   2022
# 380              Yes       1.25M               Low                   2024
# 405               No       1.25M               Low                      0

# %%
duplicates = df["Name"].value_counts()
print(duplicates[duplicates > 1])
# Out:
# Name
# Barq      2
# RevYou    2
# Marn      2
# Name: count, dtype: int64

# %% [markdown]
# ### Unique Values per Column
#
# This code iterates over all columns in the dataset and prints the number of unique values for each column, helping to understand data variety and identify potential categorical features.

# %%
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# Name: 457 unique values
# Website: 453 unique values
# Stage: 9 unique values
# Industry: 146 unique values
# Tags: 218 unique values
# Region: 7 unique values
# Startup HQ: 2 unique values
# NumOfTags: 10 unique values
# Funding (USD): 9 unique values
# CompanySize: 4 unique values
# Funding_min: 8 unique values
# rate_percent: 7 unique values
# Allign with 2030: 2 unique values
# Funding_Avg: 9 unique values
# Opportunity_Level: 3 unique values
# Year of establishment: 22 unique values

# %% [markdown]
# ### Detecting Outliers in Numeric Columns
#
# This code examines the numeric columns `NumOfTags`, `Funding_min`, and `rate_percent` for outliers using the IQR method.
# For each column, it calculates the lower and upper bounds, identifies outlier rows, and prints their count along with the corresponding company names.

# %%
numeric_cols = ['NumOfTags', 'Funding_min', 'rate_percent']

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    
    print(f"Column: {col}")
    print(f"Lower bound: {lower_bound}, Upper bound: {upper_bound}")
    print(f"Number of outliers: {outliers.shape[0]}")
    print(outliers[[col, 'Name']]) 
    print("---------------------------------------------------\n")
# Out:
# Column: NumOfTags
# Lower bound: -0.5, Upper bound: 3.5
# Number of outliers: 46
#      NumOfTags                            Name
# 190          7                     Aman Vision
# 193          4                          Declic
# 196          5                          Levers
# 205          4                      Amwal Tech
# 209         10                       Yourparts
# 228          7               Hysabat Solutions
# 231          7  Pnode Auditing |  بنود للتدقيق
# 232          4                         Nokhbah
# 238          7               FlyNow Arabia Ltd
# 240          4                          Maqsam
# 243          4                           Awfar
# 244          4                            Sahl
# 251          4                           Bynow
# 253          4                      Zerofunnel
# 262          5                  Swarm robotics
# 264          4                        Go Steer
# 266          4            Slangit Technologies
# 268          4              AQUIVIO Arabia LLC
# 272          5                    TripVlog ltd
# 276          6                           Mithu
# 284          4                       Jisr.care
# 287          4                        Carology
# 294          6                      Traderware
# 297          5                          Sniper
# 298          4                  NABD solutions
# 303          4                            LDUN
# 304          4                       UmrahCash
# 308         10                       Truc-King
# 311          7                    NMI Skyspace
# 316          7                        OpenTech
# 319          5                         gulf-el
# 320          5                  Smart Codes IT
# 321          7                      Air To MC2
# 322          5                            Unit
# 330          6                            CLST
# 331          5  OSJ for Information Technology
# 335          8                         Qantara
# 336          7                      Dunes Aero
# 349          4                   MENA Cashback
# 351          5                        DiveXcpe
# 354          8                     InteliDexer
# 358          6                 Thya Technology
# 371          4                        Cubelink
# 373          8                 MyFounders.Club
# 397          4                        Bookista
# 408          4                        Noot نوت
# ---------------------------------------------------
#
# Column: Funding_min
# Lower bound: -20000000.0, Upper bound: 36000000.0
# Number of outliers: 109
#      Funding_min         Name
# 2     50000000.0        Salla
# 16   500000000.0        Rasan
# 17   500000000.0     Nice One
# 77    50000000.0    Almosafer
# 93    50000000.0       Geidea
# ..           ...          ...
# 451  500000000.0       Baeynh
# 454  500000000.0        Seavo
# 457  500000000.0  TechiMatter
# 458  500000000.0      Payzaty
# 459  500000000.0       aFundy
#
# [109 rows x 2 columns]
# ---------------------------------------------------
#
# Column: rate_percent
# Lower bound: 75.6, Upper bound: 75.6
# Number of outliers: 101
#      rate_percent           Name
# 2           13.68          Salla
# 7           13.68       Classera
# 13          13.68       Grintafy
# 19           4.97        Paytabs
# 28          13.68          Aanab
# ..            ...            ...
# 415          2.87        ShipTag
# 452          1.92         SARSAT
# 454          1.92          Seavo
# 456          1.92  Stllr Network
# 459          1.92         aFundy
#
# [101 rows x 2 columns]
# ---------------------------------------------------

# %% [markdown]
# ### Dataset Shape After Cleaning
#
# This code displays the shape of the DataFrame after the cleaning steps and shows the first few rows to verify the changes.

# %%
print("Shape after cleaning:", df.shape)
df.head()
# Out:
# Shape after cleaning: (460, 16)
#       Name                   Website           Stage  \
# 0     Lean   https://www.leantech.me        Series B
# 1  Foodics  https://www.foodics.com/        Series C
# 2    Salla        https://salla.com/  Private Equity
# 3     Nana        https://nana.co/en        Series C
# 4     Mozn       https://www.mozn.sa    Pre-Series B
#
#                        Industry                                       Tags  \
# 0            Financial Services                     Fintech Infrastructure
# 1  Technology ,Food & Beverages                    SaaS,Financial Solution
# 2                    Technology                                       SaaS
# 3              Food & Beverages  Last Mile Delivery,Marketplace,E-Commerce
# 4                    Technology                      AI & Machine Learning
#
#    Region    Startup HQ  NumOfTags Funding (USD)      CompanySize  \
# 0  Riyadh  Saudi Arabia          1     15M – 30M  Startup / Small
# 1  Riyadh  Saudi Arabia          2     25M – 50M  Startup / Small
# 2  Makkah  Saudi Arabia          1   50M – 500M+            Large
# 3  Riyadh  Saudi Arabia          3     25M – 50M  Startup / Small
# 4  Riyadh  Saudi Arabia          1     10M – 18M        Mid-level
#
#    Funding_min  rate_percent Allign with 2030 Funding_Avg Opportunity_Level  \
# 0   15000000.0         75.60              Yes      22.50M              High
# 1   25000000.0         75.60              Yes      37.50M              High
# 2   50000000.0         13.68              Yes     275.00M              High
# 3   25000000.0         75.60              Yes      37.50M              High
# 4   10000000.0         75.60              Yes      14.00M            Medium
#
#    Year of establishment
# 0                   2019
# 1                   2014
# 2                   2016
# 3                   2016
# 4                   2017

# %% [markdown]
# # Save new dataset after collection

# %%
#df.to_csv("cleaned_dataset.csv", index=False)
#print("\nData cleaning completed. Cleaned data saved.")
